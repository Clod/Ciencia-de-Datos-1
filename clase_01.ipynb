# %% [markdown]
# ![Image in a markdown cell](https://cursos.utnba.centrodeelearning.com/pluginfile.php/1/theme_space/customlogo/1738330016/Logo%20UTN%20Horizontal.png)

# %% [markdown]
# ---

# %% [markdown]
# # **Diplomado en Ciencia de datos**

# %% [markdown]
# # **Tema 1: Introducción a la programación en Python**

# %% [markdown]
# ## **Operaciones Básicas**

# %% [markdown]
# En Python, puedes realizar una variedad de operaciones matemáticas básicas utilizando operadores aritméticos. A continuación, se describen algunas de las operaciones más comunes y cómo utilizar los operadores correspondientes:

# %% [markdown]
# **Suma**

# %%
# El signo + es el operador para indicar la suma de los valores
4+9
# Out:
# 13

# %%
# Se pueden sumar más dos valores a la vez
5+3+7
# Out:
# 15

# %%
# Que ocurre en esta suma??
'3'+ '4'
# Out:
# '34'

# %% [markdown]
# **Resta**

# %% [markdown]
# La resta entre dos valores se realiza intercalando el simbolo "-". Funciona de forma similar al operador suma

# %%
6-2
# Out:
# 4

# %% [markdown]
# **Potenciación**

# %% [markdown]
# La potenciación $a^B$, se realiza colocando la base del lado izquierdo seguido de dos astericos "**" y finalmente agregando el exponente. Ejemplo

# %%
2**3
# Out:
# 8

# %% [markdown]
# **División y División entera**

# %% [markdown]
# El operador de división se utiliza para dividir un número por otro y la operacion division siempre devuelve un numero con punto decimal. Se usa el simbolo "/". Por ejemplo:

# %%
6 / 4
# Out:
# 1.5

# %% [markdown]
# Si queremos la parte entera de la división, usamos el simbolo "//". Ejemplo

# %%
6 // 4
# Out:
# 1

# %% [markdown]
# **Resto de la división**

# %% [markdown]
# Como bien lo indica el nombre, la operación retorna el resto de realizar la división entre dos valores a y b. El simbolo que se usa es "%". Ejemplo

# %%
6 % 4
# Out:
# 2

# %% [markdown]
# ---

# %% [markdown]
# ## **ACTIVIDAD**

# %% [markdown]
# Realice la siguiente operación 10 + 3 * 5 - 4/2 y deduzca la prioridad entre las operaciones, es decir, al no tener paréntesis la operación para indicar que operación se realiza primero, Python debe decidir qué operación realizará primero y en qué orden. Puedes establecer este orden?

# %%
10+3*5-4/2
# Out:
# 23.0

# %% [markdown]
# ---

# %% [markdown]
# ## **Variables y Tipos de Datos**

# %% [markdown]
# Las **variables** son expresiones sumamente importantes en cualquier lenguaje de programación y que son utilizadas para almacenar valores en un espacio en la memoria del computador, para luego volver acceder a ellos cada vez que sea necesario. Con las variables podemos realizar operaciones y generar nuevas variables o modificar las ya existentes.
#
# En Python, así como en otros lenguales existen ciertos criterios o normas que se deben tener en cuenta a la hora de crear una variable. Por ejemplo:
#
#
# *   No puede comenzar con un número.
# *   No puede contener espacios.
# *   No puede tener simbolos especiales (#á-¿?ñ)
# *   Para crear un espacio podemos usar el símbolo "_"
# *   Python distingue los nombres de variables entre mayúsculas y minúsculas.
# *   Deben usarse nombres representativos que indique el valor que almacena
# *   Si la variable está formada por dos o más palabras debe estar separadas por un guion bajo "_"
# *   No se pueden usar variables reservadas en Python
#
# Para asignar un valor a una variable solamente debemos colocar el signo "=" después del nombre de la variable y seguidamente el valor que tomará dicha variable.

# %% [markdown]
# **Ejemplo de variables**

# %% [markdown]
# **Asignar valor a una variable**

# %%
x = 5

# %%
variable1 = 3.14

# %%
variable2 = "Yo soy una variable"

# %% [markdown]
# **Recuperar el valor de una variable**

# %% [markdown]
# Para verificar el valor de una variable podemos imprimir su valor por pantalla usando el comando print() o solamente escribir el nombre de la variable y presionar **shift + enter**

# %%
# usando el comando print()
print('El valor de la variable x es x =', x)
# Out:
# El valor de la variable x es x = 5

# %%
# Retornando solo el valor de la variable sin el comando print()
x
# Out:
# 5

# %%
# Igual para el resto de las variables cargadas en memoria
variable1
# Out:
# 3.14

# %% [markdown]
# **Ejemplo**

# %% [markdown]
# Supongamos que tenemos un conjunto de valores que corresponden a la altura en centimetros en un conjunto de personas y las medidas son las siguientes 150, 183, 165, 173. Si queremos calcula la estatura promedio y almacenar en una variable podemos hacer lo siguiente:

# %%
# Definimos una variable con un nombre representativo y usamos las operaciones
# aprendida para realizar el calculo
estatura_promedio = (150 + 183 + 165 + 173) / 4

# %%
# Vamos a mostrar por pantalla el calculo junto con un mensaje.
# En este caso le indicaremos que queremos que se imprima con 3 decimales.
print("La estatura promedio de las personas es {:.3f} cms".format(estatura_promedio))
# Out:
# La estatura promedio de las personas es 167.750 cms

# %% [markdown]
# **Declaración múltiples**
#
# La declaración múltiple de variables es una característica de Python que te permite declarar varias variables en una sola línea. Esta característica es especialmente útil cuando deseas asignar múltiples valores a múltiples variables en una sola sentencia. Aquí tienes un ejemplo de declaración múltiple:

# %%
nombre, edad, año_nacimiento = 'Carlos', 31, 1989

# %%
nombre
# Out:
# 'Carlos'

# %%
edad
# Out:
# 31

# %%
año_nacimiento
# Out:
# 1989

# %% [markdown]
# ### **Tipos de datos**

# %% [markdown]
# Python tiene los siguientes tipos de datos integrados de forma predeterminada y están agrupados en las siguiente categorias:
#
# *  Enteros(int)
# *  Numero de punto flotante (float)
# *  Cadena de caracteres (str)
# *  Booleanos (bool)
# *  Valor None (None)

# %% [markdown]
# Para saber el tipo de dato de una variable podemos usar el comando **type()**

# %% [markdown]
# **Ejemplo:**

# %%
valor1 = 12

# %%
type(valor1)
# Out:
# int

# %%
valor2 = 12.3

# %%
type(valor2)
# Out:
# float

# %%
valor3 = 'Hola mundo'

# %%
type(valor3)
# Out:
# str

# %% [markdown]
# ### **Variables de tipo entero**

# %% [markdown]
# Las **variables de tipo entero (int)** son variables que contiene valores numéricos sin decimales. Son utilizadas para representar cantidades enteras, por ejemplo número de camiones, número de personas, etc

# %%
cantidad_camiones = 6

# %%
type(cantidad_camiones)
# Out:
# int

# %% [markdown]
# Con las variables enteras podemos realizar las siguientes operaciones:
# **suma, resta, división, multiplicación, modulo, potenciación**, las cuales vimos previamente

# %% [markdown]
# ### **Variables de tipo float**

# %% [markdown]
# Las variables tipo flotante o float son varibles numéricas que contienen una parte decimal.

# %%
variable_float = 12.3

# %%
type(variable_float)
# Out:
# float

# %% [markdown]
# Con las variables de tipo float podemos realizar las siguientes operaciones:
# **suma, resta, división, multiplicación, potenciación**.

# %% [markdown]
# ### **Variables de tipo String**

# %% [markdown]
# Las variables tipo **string** están formadas por cadenas de caracteres y se usan para representar texto. Para que Python reconozca este tipo de variables, es necesario que se encuentren encerradas entre comillas simples ' ' o comillas dobles " "

# %% [markdown]
# **Ejemplo**

# %%
var1 = 'Hola'
var2 = 'Mundo'

# %%
print(type(var1), type(var2))
# Out:
# <class 'str'> <class 'str'>

# %% [markdown]
# ### **Operaciones con strings**
#
# *  **Concatenación:**
# Los strings se pueden unir para formar strings más largos. Existen varias
# formas de unir o concatenar strings, una forma es usando el simbolo "+". Como ya vimos en variables numéricas se usa para sumar y para variables tipo string
# se usa para concatenar.

# %%
# Creamos una nueva variable a partir de las variables var1 y var2
var3 = var1 + ' ' + var2

# %%
print(var3)
# Out:
# Hola Mundo

# %% [markdown]
# Otra forma de concatenar strings es usando los **f-string**. Es una forma práctica de agregar el valor de una variable a un string. para realizarlo debes agregarle al string la letra f al inicio y escribir dentro del string encerrado entre llaves {} la variable que quieras agregar. Veamos un ejemplo.

# %%
dia = 'Martes'
hora = '5:15'

# %%
print(f"Nos vemos el dia {dia} a las {hora}")
# Out:
# Nos vemos el dia Martes a las 5:15

# %%
concatenado = f"La concatenación es: {dia} {hora}"
concatenado
# Out:
# 'La concatenación es: Martes 5:15'

# %% [markdown]
# ### **Convertir texto a mayúscula/minuscula**

# %%
texto = 'texto de ejemplo'

# %%
# Usamos el método upper() para convertir a mayúscula
texto_mayuscula = texto.upper()

# %%
texto_mayuscula
# Out:
# 'TEXTO DE EJEMPLO'

# %%
texto_minuscula = texto_mayuscula.lower()

# %%
texto_minuscula
# Out:
# 'texto de ejemplo'

# %% [markdown]
# ### **Primera letra en mayúscula (Capitalize)**

# %%
# Usamos el método capitalize() para convertir a mayúscula el primer caracter del string
texto_capitalizado = texto.capitalize()

# %%
texto_capitalizado
# Out:
# 'Texto de ejemplo'

# %% [markdown]
# ### **Separación de string**
#
# Para separar un string podemos usar el método split(), el cual nos permite separar un string en el caracter que se le indique como parámetro

# %%
# Separamos usando los espacios en blanco
texto.split()
# Out:
# ['texto', 'de', 'ejemplo']

# %%
# Separación por la letra e
texto.split('e')
# Out:
# ['t', 'xto d', ' ', 'j', 'mplo']

# %% [markdown]
# ### **Longitud de un string**

# %% [markdown]
# Podemos facilmente determinar la longitud de un string usando el método len()

# %%
len(texto)
# Out:
# 16

# %% [markdown]
# ### **Subcadenas de strings**

# %% [markdown]
# Podemos seleccionar elementos de un string a partir de un indice o seleccionar porciones de éste agregando el recorrido de valores que se quieren abarcar.

# %%
# Seleccionamos el primer elemento del string. en Python los indices comienzan desde cero.
texto[0]
# Out:
# 't'

# %%
# Ahora seleccionemos una subcadena de la variable "texto" tomando los primeros 3 caracteres de la variable
texto[0:3]
# Out:
# 'tex'

# %%
# Texto intermedio
texto[3:7]
# Out:
# 'to d'

# %%
# último valor del string
texto[-1]
# Out:
# 'o'

# %% [markdown]
# ---

# %% [markdown]
# ## **ACTIVIDAD**

# %% [markdown]
# 1) Se puede usar el comando input() para la entrada de datos y almacenar su valor
# en una variable. En esta actividad deberá crear un f-string que le permita dar un saludo personalizado que contenga el **nombre, apellido,edad, procedencia y profesión**. Cada variable debe ser ingresada por el teclado usando el comando input() y finalmente imprimir el saludo por pantalla

# %%
# Continua el código aquí
nombre = input('Ingrese su nombre: ')

# Continua con el resto de las variables
apellido = input('Ingrese su apellido: ')

# Crea el f-string
print(f"Hola {nombre} {apellido}")
# Out:
# Hola Claudio Grasso

# %% [markdown]
# 2) Ahora modifica el codigo anterior de tal manera que el nombre y el apellido impreso en pantalla comiencen con mayúscula y que la profesión este completamente en mayúscula.

# %%
# Agrega el código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### **Variables de tipo Booleano**

# %% [markdown]
# Una variable booleana, es aquella que solo admite dos valores. verdadero (True) o falsa (False)

# %%
# Vamos a definir una variable booleana

variable_booleana=True

# %%
# Tipo de dato
type(variable_booleana)
# Out:
# bool

# %% [markdown]
# Para **cambiar su valor de verdad** de una variable booleana podemos utilizar el operador lógico "not".

# %%
# Cambia el valor de la variable a False

not variable_booleana
# Out:
# False

# %% [markdown]
# **Las variables booleanas pueden ser el resultado de comparaciones lógicas y nos permite verificar si alguna condición se cumple o no.**]

# %% [markdown]
# #### Comparemos dos números y veamos el resultado que retorna. En este caso estamos utilizando el operador relacional
# **"mayor que >"**

# %%
# En este caso se está comparando si 5 es mayor que 3
5>3
# Out:
# True

# %%
# Repetimos la pregunta pero con el operador "menor que <"
5<3
# Out:
# False

# %% [markdown]
# #### También podemos comparar string. El simbolo "==" se usa para comparar si dos variables son iguales, y el simbolo "!=" se usa para ver si dos variables son diferentes.

# %%
# Serán iguales?? #
"hola"=="Hola"
# Out:
# False

# %%
"hola"!="Hola"
# Out:
# True

# %%
"hola".capitalize() =="Hola"
# Out:
# True

# %% [markdown]
# ## **Estructuras de datos básicas**

# %% [markdown]
# Las estructuras de datos son aquellos objetos que se usan para almacenar información.
# Hay muchos tipos, pero estos son los básicos en python:
#
# * Listas
# * Tuplas
# * Diccionarios
# * Conjuntos

# %% [markdown]
# ### **Listas**
# Las listas son conjuntos de elementos ordenados donde cada elemento tiene una posición. Las listas comienzan y terminan con corchetes, y cada elemento de la lista están separados entre si por una coma.
#
# **Mutable:** Las listas son estructuras de datos mutables, lo que significa que puedes modificar sus elementos, agregar nuevos elementos o eliminar elementos existentes.
#
# **Ordenada:** Los elementos en una lista mantienen un orden específico, lo que significa que puedes acceder a ellos por su posición, empezando desde el índice 0 hasta el índice n-1, donde n es el número total de elementos en la lista.
#
# **Heterogénea:** Las listas pueden contener elementos de diferentes tipos de datos. Por ejemplo, puedes tener una lista que contenga números enteros, cadenas de caracteres, flotantes, u otros tipos de datos.
#
# **Indexación y segmentación:** Puedes acceder a elementos individuales de una lista utilizando su índice, y también puedes usar la segmentación (slicing) para obtener sublistas o para modificar varios elementos a la vez.
#
# **Iterable:** Puedes recorrer los elementos de una lista utilizando un bucle for, lo que la hace compatible con las estructuras de control de flujo de Python como los bucles for.
#
# **Puede contener elementos duplicados:** A diferencia de los conjuntos (sets), las listas pueden contener elementos duplicados.
#
# **Flexible:** Las listas pueden cambiar de tamaño dinámicamente, lo que significa que puedes agregar nuevos elementos, eliminar elementos existentes o modificar elementos sin necesidad de crear una nueva lista.
#
# Se definen utilizando corchetes [ ] y separando los elementos con comas.

# %% [markdown]
# **Ejemplo**

# %%
# Lista de nombres. Cada nombre de la lista es un string
nombres=["Pedro","Carlos", "Juan", "María","Luisa"]
nombres
# Out:
# ['Pedro', 'Carlos', 'Juan', 'María', 'Luisa']

# %% [markdown]
# Podemos conocer la longitud de elementos que conforman una lista con el comando **"len()"**

# %%
len(nombres)
# Out:
# 5

# %% [markdown]
# Cada elemento de la lista le corresponde un índice, con el cuál podemos acceder a su valor. Los índices de las listas en Python comienzan siempre en 0. Para acceder debemos colocar el nombre de la variable seguida de corchetes encerrando el índice al cual queremos tener acceso. Veamos algunos ejemplos para la variable nombres.

# %%
# Primer elemento de la lista
nombres[0]
# Out:
# 'Pedro'

# %%
# Tercer elemento de la lista
nombres[2]
# Out:
# 'Juan'

# %% [markdown]
# Podemos visualizar porciones de elementos de la lista [inicio:final-1:orden]

# %%
# Todos los elementos de la lista nombres anteriores al indice 3

nombres[:3]
# Out:
# ['Pedro', 'Carlos', 'Juan']

# %%
# Todos los elementos de la lista nombres a partir del indice 2

nombres[2:]
# Out:
# ['Juan', 'María', 'Luisa']

# %%
# Podemos usar ídices negativos, con lo cual Python hace la lectura a partir del último elemento.
# El último elemento de la lista le corresponde el índice -1, si vamos a utilizar indices negativos

nombres[-1]
# Out:
# 'Luisa'

# %% [markdown]
# #### **Buscar elementos en una lista**

# %% [markdown]
# Veamos por ejemplo si el nombre "Carlos" está en la lista de nombres

# %%
"Carlos" in nombres
# Out:
# True

# %% [markdown]
# Con o anterior identificamos si un elemento está dentro de una lista, pero no sabemos su ubicación.
# Para ellos usemos el método **"index()"**

# %%
print(f"El nombre Carlos se encuentra en el índice {nombres.index('Carlos')} de la lista nombres")
# Out:
# El nombre Carlos se encuentra en el índice 1 de la lista nombres

# %%
# Aquí podemos corroborarlos

nombres[1]
# Out:
# 'Carlos'

# %% [markdown]
# #### **Eliminar elementos de una lista**

# %% [markdown]
# Con el método "pop()" podemos eliminar un elemento ubicado enuna determinada posición. Por ejemplo, eliminemos a "Carlos" de la lista anterior.

# %%
nombres.pop(1)
# Out:
# 'Carlos'

# %%
# Si imprimimos la lista nuevamente, vemos que "Carlos" ya no es parte de la lista

nombres
# Out:
# ['Pedro', 'Juan', 'María', 'Luisa']

# %% [markdown]
# #### **Insertar elementos en una lista**

# %%
# Vamos a agregar nuevamente el nombre "Carlos" a la lista en la misma posición, para ello hacemos lo siguiente:

nombres.insert(1,"Carlos")

# %%
nombres
# Out:
# ['Pedro', 'Carlos', 'Juan', 'María', 'Luisa']

# %% [markdown]
# #### **Agregar elementos a una lista**

# %% [markdown]
# Podemos usar el método **"append(objeto)"** para agregar un elemento al final de la lista...Voy a agregar mi nombre a la lista. Agrega el tuyo si quieres

# %%
nombres.append("Roman")

# %%
nombres
# Out:
# ['Pedro', 'Carlos', 'Juan', 'María', 'Luisa', 'Roman']

# %% [markdown]
# #### **Ordenando los elementos de una lista**

# %% [markdown]
# Podemos ordenar una lista por orden ascendente, descendente o por orden alfabético con el método "sort()"

# %%
nombres.sort()

# %%
# Aquí vemos como la lista está ordenada alfabeticamente
nombres
# Out:
# ['Carlos', 'Juan', 'Luisa', 'María', 'Pedro', 'Roman']

# %% [markdown]
# Si queremos invertir el orden, podemos colocar el parámetro "reverse" del método sort() en **True**. Por defecto este parametro está como false.

# %%
nombres.sort(reverse=True)

# %%
nombres
# Out:
# ['Roman', 'Pedro', 'María', 'Luisa', 'Juan', 'Carlos']

# %% [markdown]
# #### **Invertir el orden de una lista**

# %% [markdown]
# Consideremos la siguiente lista numérica:

# %%
lista=[3,5,2,4,9]

# %% [markdown]
# Si queremos invertir el orden, podemos usar el método **reverse()**, con lo cual la lista queda ordenada de atrás hacia adelante

# %%
lista.reverse()

# %%
lista
# Out:
# [9, 4, 2, 5, 3]

# %% [markdown]
# ## **Tuplas**
#
# Las tuplas son similares a las listas, solamente que se definen encerrando sus elementos entre parentesis.
#
# Tienen las siguientes características:
#
# **Inmutable:** A diferencia de las listas, las tuplas son estructuras de datos inmutables, lo que significa que una vez creadas, no se pueden modificar sus elementos. Sin embargo, es importante tener en cuenta que si los elementos de la tupla son mutables (por ejemplo, listas), estos elementos aún pueden ser modificados.
#
# **Ordenada:** Al igual que las listas, los elementos en una tupla mantienen un orden específico, lo que permite acceder a ellos por su posición utilizando índices.
#
# **Heterogénea:** Las tuplas pueden contener elementos de diferentes tipos de datos, al igual que las listas. Esto significa que puedes tener una tupla que contenga números enteros, cadenas de caracteres, flotantes, u otros tipos de datos.
#
# **Indexación y segmentación: **Puedes acceder a elementos individuales de una tupla utilizando su índice, y también puedes usar la segmentación (slicing) para obtener sub-tuplas o para acceder a varios elementos a la vez.
#
# **Eficiencia:** Las tuplas son más eficientes en términos de uso de memoria y rendimiento que las listas, especialmente cuando se trata de iterar sobre ellas o pasarlas como argumentos a funciones.
#
# **Uso de paréntesis:** Las tuplas se definen utilizando paréntesis (), aunque en muchos casos, para claridad, es común incluir elementos separados por comas sin necesidad de paréntesis.
#
# **Útiles para datos inmutables:** Las tuplas son útiles cuando necesitas una colección de elementos que no deban ser modificados, como por ejemplo, las coordenadas de un punto en un espacio bidimensional.

# %% [markdown]
# **Ejemplo**

# %%
frutas=("limón","cambur", "fresas","naranja")

# %%
frutas
# Out:
# ('limón', 'cambur', 'fresas', 'naranja')

# %%
# Veamos el tipo de variable

type(frutas)
# Out:
# tuple

# %%
# Podemos acceder a sus elementos igual que las listas

frutas[0]
# Out:
# 'limón'

# %% [markdown]
# Tratemos de cambiar un elemento de la tupla...

# %%
frutas[0]="pera"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 frutas[0]="pera"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Como vemos en el mensaje de error, las tuplas no soportan la asignación de elementos

# %% [markdown]
# ### **Diccionarios**
#
# **Estructura de datos clave-valor:** Los diccionarios son estructuras de datos que almacenan pares clave-valor, donde cada valor está asociado con una clave única. Esto permite una rápida recuperación de valores basada en sus claves.
#
# **Mutable:** Los diccionarios son estructuras de datos mutables, lo que significa que puedes modificar, agregar o eliminar pares clave-valor después de su creación.
#
# **No ordenados:** Mantiene el orden de inserción, lo que significa que los elementos se ordenan según el orden en que fueron insertados.
#
# **Flexibilidad en los tipos de datos:** Los valores en un diccionario pueden ser de cualquier tipo de datos (números, cadenas, listas, tuplas, diccionarios, etc.). Las claves, sin embargo, deben ser de un tipo de datos inmutable, como cadenas de caracteres, números o tuplas.
#
# **Eficiencia en la búsqueda:** La búsqueda de valores en un diccionario se realiza de manera muy eficiente, independientemente del tamaño del diccionario, ya que utiliza una técnica llamada tabla hash para indexar y recuperar los valores.
#
# **Las claves son únicas:** En un diccionario, cada clave debe ser única. Si intentas agregar una clave que ya existe, el valor asociado con esa clave se sobrescribirá con el nuevo valor.
#
# **Iterabilidad:** Puedes iterar sobre un diccionario utilizando bucles for para acceder a sus claves, valores o pares clave-valor.
#
# **Flexibilidad en la manipulación de datos:** Los diccionarios son muy útiles para almacenar y manipular datos estructurados de una manera flexible y eficiente.

# %% [markdown]
# **Ejemplo de diccionario**

# %%
# Creamos la variable recetas, el cual es una variable tipo diccionario.
# Las claves son agua, aceite, harina y azucar y los valores correspondientes
# 3, 2, 6 5 respectivamente.

receta={"agua": 3,"aceite": 2,"harina":6, "azucar": 5}

# %%
# Veamos su tipo

type(receta)
# Out:
# dict

# %%
# Acá a diferencia de las listas que tenemos acceso a través de sus indices, acá necesitamos pasar como argumento la clave para
# así tener el valor correspondiente.

receta["agua"]
# Out:
# 3

# %%
receta["harina"]
# Out:
# 6

# %% [markdown]
# #### **Obteniendo las claves y valores de un diccionario**

# %% [markdown]
# Para obtener las claves de un diccionario utilizamos el **método keys()**

# %%
# Claves del diccionario

receta.keys()
# Out:
# dict_keys(['agua', 'aceite', 'harina', 'azucar'])

# %% [markdown]
# Podemos convertir la expresión de salida en una lista usando la función **list()**

# %%
list(receta.keys())
# Out:
# ['agua', 'aceite', 'harina', 'azucar']

# %% [markdown]
# Para el caso de los valores existe un método análogo que nos permite obtener todos los valores. Vamos a obtener una lista como en el ejemplo anterior.

# %%
list(receta.values())
# Out:
# [3, 2, 6, 5]

# %% [markdown]
# También podemos determinar si un diccionario tiene como clave determinado valor, usando el comando "in" del cual ya hicimos uso cuando se habló de las listas.

# %%
"agua" in receta
# Out:
# True

# %% [markdown]
# ### **Estructura más complejas**
#
# Cada una de las estructuras anteriores puede contener a las demás. Podemos crear listas de listas. listas de diccionarios, diccionarios con tuplas, etc. Veamos algunos ejemplos:

# %% [markdown]
# #### **Diccionarios y tuplas**

# %%
paises={"Argentina":("Suramerica",'Buenos Aires'), "Colombia":("Suramerica",'Bogotá'), "Canadá": ("Nortearmerica","Otawa")}

# %%
paises['Argentina']
# Out:
# ('Suramerica', 'Buenos Aires')

# %% [markdown]
# #### **Listas de listas**

# %%
animales=[["Dalmata","Poodle","Pug Carlino"],["Canario","loro","Aguila","Halcón"],["Angora","Siames","Persa"]]

# %%
animales[0]
# Out:
# ['Dalmata', 'Poodle', 'Pug Carlino']

# %%
animales[1]
# Out:
# ['Canario', 'loro', 'Aguila', 'Halcón']

# %% [markdown]
# #### **Listas y Diccionarios**

# %%
lista = [[1,2,3],{"clave":"valor"}, (2,8)]

# %%
# Primer elemento es una lista

type(lista[0])
# Out:
# list

# %%
# Segundo elemento es un diccionario

type(lista[1])
# Out:
# dict

# %%
# tercer elemento es una tupla

type(lista[2])
# Out:
# tuple
